# %% [markdown]
# ### Import libraries

# %%
import cdt

from cdt.metrics import precision_recall, SID, SHD

from utils.graph_functions import load_graph_from_json, is_path, check_graph, evaluate_graphs

import json
import os
# Out:
# Detecting 2 CUDA device(s).
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %%
#cdt.SETTINGS.rpath = '' # path to Rscript executable

# %% [markdown]
# ### Load data

# %%
test_name = 'results_ada_ablation_20_noise_20_iter'

is_real_data = True

# %%
if is_real_data:
    graphs_path = 'results_real/' + test_name + '/'
else:
    graphs_path = 'results_synthetic/' + test_name + '/'

# %%
folder_list = os.listdir(graphs_path)
graphs_models_dict = {}

true_graphs = {}

for folder in folder_list:

    if folder == 'real_graph':
        if is_real_data:
            true_graphs['real'] = load_graph_from_json(graphs_path + folder + '/' + os.listdir(graphs_path + folder)[0])

    else:
        graphs_dict = {}

        for noise_level in range(6): # 21
            graphs_dict[str(noise_level)] = None
            if not is_real_data:
                true_graphs[str(noise_level)] = None


        file_list = os.listdir(graphs_path + folder)
        for file in file_list:
            try:
                name_dir = graphs_path + folder + '/' + file

                graph = load_graph_from_json(name_dir)

                noise_level = file.split('_')[2]
                if graphs_dict[noise_level] is None:
                    graphs_dict[noise_level] = []
                graphs_dict[noise_level].append(graph)

                if not is_real_data:
                    true_graph = load_graph_from_json(graphs_path + 'real_graph/' + file)
                    if true_graphs[noise_level] is None:
                        true_graphs[noise_level] = []
                    true_graphs[noise_level].append(true_graph)

            except:
                print(f'Error loading {file}')
                continue

        for noise_level in graphs_dict:
            if graphs_dict[noise_level] is None:
                graphs_dict[noise_level] = []

        graphs_models_dict[folder] = graphs_dict
# Out:
# Error loading graph_noise_6_it_13.json
# Error loading graph_noise_6_it_6.json
# Error loading graph_noise_6_it_9.json
# Error loading graph_noise_6_it_10.json
# Error loading graph_noise_6_it_5.json
# Error loading graph_noise_6_it_4.json
# Error loading graph_noise_6_it_3.json
# Error loading graph_noise_6_it_1.json
# Error loading graph_noise_6_it_2.json
# Error loading graph_noise_6_it_11.json
# Error loading graph_noise_6_it_12.json
# Error loading graph_noise_6_it_7.json
# Error loading graph_noise_6_it_8.json
# Error loading graph_noise_6_it_13.json
# Error loading graph_noise_6_it_6.json
# Error loading graph_noise_6_it_9.json
# Error loading graph_noise_6_it_10.json
# Error loading graph_noise_6_it_5.json
# Error loading graph_noise_6_it_4.json
# Error loading graph_noise_6_it_3.json
# Error loading graph_noise_6_it_1.json
# Error loading graph_noise_6_it_2.json
# Error loading graph_noise_6_it_11.json
# Error loading graph_noise_6_it_12.json
# Error loading graph_noise_6_it_7.json
# Error loading graph_noise_6_it_8.json
# Error loading graph_noise_6_it_13.json
# Error loading graph_noise_6_it_6.json
# Error loading graph_noise_6_it_9.json
# Error loading graph_noise_6_it_10.json
# Error loading graph_noise_6_it_5.json
# Error loading graph_noise_6_it_4.json
# Error loading graph_noise_6_it_3.json
# Error loading graph_noise_6_it_1.json
# Error loading graph_noise_6_it_2.json
# Error loading graph_noise_6_it_11.json
# Error loading graph_noise_6_it_12.json
# Error loading graph_noise_6_it_7.json
# Error loading graph_noise_6_it_8.json
# Error loading graph_noise_6_it_13.json
# Error loading graph_noise_6_it_6.json
# Error loading graph_noise_6_it_9.json
# Error loading graph_noise_6_it_10.json
# Error loading graph_noise_6_it_5.json
# Error loading graph_noise_6_it_4.json
# Error loading graph_noise_6_it_3.json
# Error loading graph_noise_6_it_1.json
# Error loading graph_noise_6_it_2.json
# Error loading graph_noise_6_it_11.json
# Error loading graph_noise_6_it_12.json
# Error loading graph_noise_6_it_7.json
# Error loading graph_noise_6_it_8.json
# Error loading graph_noise_6_it_6.json
# Error loading graph_noise_6_it_9.json
# Error loading graph_noise_6_it_10.json
# Error loading graph_noise_6_it_5.json
# Error loading graph_noise_6_it_4.json
# Error loading graph_noise_6_it_3.json
# Error loading graph_noise_6_it_1.json
# Error loading graph_noise_6_it_2.json
# Error loading graph_noise_6_it_11.json
# Error loading graph_noise_6_it_12.json
# Error loading graph_noise_6_it_7.json
# Error loading graph_noise_6_it_8.json
# Error loading graph_noise_6_it_13.json
# Error loading graph_noise_6_it_6.json
# Error loading graph_noise_6_it_9.json
# Error loading graph_noise_6_it_10.json
# Error loading graph_noise_6_it_5.json
# Error loading graph_noise_6_it_4.json
# Error loading graph_noise_6_it_3.json
# Error loading graph_noise_6_it_1.json
# Error loading graph_noise_6_it_2.json
# Error loading graph_noise_6_it_11.json
# Error loading graph_noise_6_it_12.json
# Error loading graph_noise_6_it_7.json
# Error loading graph_noise_6_it_8.json

# %%
results = evaluate_graphs(graphs_models_dict, true_graphs, is_real_data)
# Out:
# Evaluating method: NO_BOOTS, Noise level: 0
# Evaluating method: NO_BOOTS, Noise level: 1
# Evaluating method: NO_BOOTS, Noise level: 2
# Evaluating method: NO_BOOTS, Noise level: 3
# Evaluating method: NO_BOOTS, Noise level: 4
# Evaluating method: NO_BOOTS, Noise level: 5
# Evaluating method: NO_MISS, Noise level: 0
# Evaluating method: NO_MISS, Noise level: 1
# Evaluating method: NO_MISS, Noise level: 2
# Evaluating method: NO_MISS, Noise level: 3
# Evaluating method: NO_MISS, Noise level: 4
# Evaluating method: NO_MISS, Noise level: 5
# Evaluating method: FULL, Noise level: 0
# Evaluating method: FULL, Noise level: 1
# Evaluating method: FULL, Noise level: 2
# Evaluating method: FULL, Noise level: 3
# Evaluating method: FULL, Noise level: 4
# Evaluating method: FULL, Noise level: 5
# Evaluating method: NO_PERM, Noise level: 0
# Evaluating method: NO_PERM, Noise level: 1
# Evaluating method: NO_PERM, Noise level: 2
# Evaluating method: NO_PERM, Noise level: 3
# Evaluating method: NO_PERM, Noise level: 4
# Evaluating method: NO_PERM, Noise level: 5
# Evaluating method: NO_MISS_PENALTY, Noise level: 0
# Evaluating method: NO_MISS_PENALTY, Noise level: 1
# Evaluating method: NO_MISS_PENALTY, Noise level: 2
# Evaluating method: NO_MISS_PENALTY, Noise level: 3
# Evaluating method: NO_MISS_PENALTY, Noise level: 4
# Evaluating method: NO_MISS_PENALTY, Noise level: 5
# Evaluating method: NO_REG, Noise level: 0
# Evaluating method: NO_REG, Noise level: 1
# Evaluating method: NO_REG, Noise level: 2
# Evaluating method: NO_REG, Noise level: 3
# Evaluating method: NO_REG, Noise level: 4
# Evaluating method: NO_REG, Noise level: 5

# %%
# Save results to a JSON file
if is_real_data:
    save_path = f'graph_metrics/real_{test_name}.json'
else:
    save_path = f'graph_metrics/synthetic_{test_name}.json'

with open(save_path, 'w') as f:
    json.dump(results, f, indent=4)
