# %% [markdown]
# ### Import libraries

# %%
import cdt

from cdt.metrics import precision_recall, SID, SHD

from utils.graph_functions import load_graph_from_json, is_path, check_graph, evaluate_graphs

import json
import os
# Out:
# No GPU automatically detected. Setting SETTINGS.GPU to 0, and SETTINGS.NJOBS to cpu_count.
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %%
cdt.SETTINGS.rpath = 'C:\\Program Files\\R\\R-4.5.1\\bin\\Rscript'

# %% [markdown]
# ### Load data

# %%
test_name = 'results_lingam_20_noise_20_iter'
is_real_data = True

if is_real_data:
    graphs_path = 'results_real/' + test_name + '/'
else:
    graphs_path = 'results_synthetic/' + test_name + '/'

# %%
folder_list = os.listdir(graphs_path)
graphs_models_dict = {}

true_graphs = {}

for folder in folder_list:

    if folder == 'real_graph':
        if is_real_data:
            true_graphs['real'] = load_graph_from_json(graphs_path + folder + '/' + os.listdir(graphs_path + folder)[0])
        else:
            file_list = os.listdir(graphs_path + folder)
            for file in file_list:
                noise_level = file.split('_')[2]
                iteration = str(int(file.split('_')[4].split('.')[0]) - 1)
                true_graphs[f'{noise_level}_{iteration}'] = load_graph_from_json(graphs_path + folder + '/' + file)

    else:
        graphs_dict = {}

        for noise_level in range(21):
            graphs_dict[str(noise_level)] = None


        file_list = os.listdir(graphs_path + folder)
        for file in file_list:
            try:
                name_dir = graphs_path + folder + '/' + file

                graph = load_graph_from_json(name_dir)

                noise_level = file.split('_')[2]
                if graphs_dict[noise_level] is None:
                    graphs_dict[noise_level] = []
                graphs_dict[noise_level].append(graph)
            except:
                print(f'Error loading {file}')
                continue

        for noise_level in graphs_dict:
            if graphs_dict[noise_level] is None:
                graphs_dict[noise_level] = []

        graphs_models_dict[folder] = graphs_dict

# %%
results = evaluate_graphs(graphs_models_dict, true_graphs, is_real_data)
# Out:
# Evaluating method: LiNGAMAlgorithm, Noise level: 0
# Evaluating method: LiNGAMAlgorithm, Noise level: 1
# Evaluating method: LiNGAMAlgorithm, Noise level: 2
# Evaluating method: LiNGAMAlgorithm, Noise level: 3
# Evaluating method: LiNGAMAlgorithm, Noise level: 4
# Evaluating method: LiNGAMAlgorithm, Noise level: 5
# Evaluating method: LiNGAMAlgorithm, Noise level: 6
# Evaluating method: LiNGAMAlgorithm, Noise level: 7
# Evaluating method: LiNGAMAlgorithm, Noise level: 8
# Evaluating method: LiNGAMAlgorithm, Noise level: 9
# Evaluating method: LiNGAMAlgorithm, Noise level: 10
# Evaluating method: LiNGAMAlgorithm, Noise level: 11
# Evaluating method: LiNGAMAlgorithm, Noise level: 12
# Evaluating method: LiNGAMAlgorithm, Noise level: 13
# Evaluating method: LiNGAMAlgorithm, Noise level: 14
# Evaluating method: LiNGAMAlgorithm, Noise level: 15
# Evaluating method: LiNGAMAlgorithm, Noise level: 16
# Evaluating method: LiNGAMAlgorithm, Noise level: 17
# Evaluating method: LiNGAMAlgorithm, Noise level: 18
# Evaluating method: LiNGAMAlgorithm, Noise level: 19
# Evaluating method: LiNGAMAlgorithm, Noise level: 20
# Evaluating method: NALiNGAMAlgorithm, Noise level: 0
# Evaluating method: NALiNGAMAlgorithm, Noise level: 1
# Evaluating method: NALiNGAMAlgorithm, Noise level: 2
# Evaluating method: NALiNGAMAlgorithm, Noise level: 3
# Evaluating method: NALiNGAMAlgorithm, Noise level: 4
# Evaluating method: NALiNGAMAlgorithm, Noise level: 5
# Evaluating method: NALiNGAMAlgorithm, Noise level: 6
# Evaluating method: NALiNGAMAlgorithm, Noise level: 7
# Evaluating method: NALiNGAMAlgorithm, Noise level: 8
# Evaluating method: NALiNGAMAlgorithm, Noise level: 9
# Evaluating method: NALiNGAMAlgorithm, Noise level: 10
# Evaluating method: NALiNGAMAlgorithm, Noise level: 11
# Evaluating method: NALiNGAMAlgorithm, Noise level: 12
# Evaluating method: NALiNGAMAlgorithm, Noise level: 13
# Evaluating method: NALiNGAMAlgorithm, Noise level: 14
# Evaluating method: NALiNGAMAlgorithm, Noise level: 15
# Evaluating method: NALiNGAMAlgorithm, Noise level: 16
# Evaluating method: NALiNGAMAlgorithm, Noise level: 17
# Evaluating method: NALiNGAMAlgorithm, Noise level: 18
# Evaluating method: NALiNGAMAlgorithm, Noise level: 19
# Evaluating method: NALiNGAMAlgorithm, Noise level: 20

# %%
# Save results to a JSON file
if is_real_data:
    save_path = f'graph_metrics/real_{test_name}.json'
else:
    save_path = f'graph_metrics/synthetic_{test_name}.json'
with open(save_path, 'w') as f:
    json.dump(results, f, indent=4)
